# %% [markdown]
# This week we are tasked with exploring Linear and Logistic Regression models to predict an outcome. Based on our initial Exploratory analysis, we will perform feature extraction and analysis to determine what relevant features can be used to build our model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing data
openpolicing_path="ma_statewide_2020_04_01.csv"

data=pd.read_csv(openpolicing_path,low_memory=False)

# %%
data.head()
# Out:
#    raw_row_number        date       location       county_name  subject_age  \
# 0               1  2007-06-06  MIDDLEBOROUGH   Plymouth County         33.0
# 1               2  2007-06-07        SEEKONK    Bristol County         36.0
# 2               3  2007-06-07        MEDFORD  Middlesex County         56.0
# 3               4  2007-06-07        MEDFORD  Middlesex County         37.0
# 4               5  2007-06-07        EVERETT  Middlesex County         22.0
#
#   subject_race subject_sex       type arrest_made citation_issued  ...  \
# 0        white        male  vehicular       False            True  ...
# 1        white        male  vehicular       False           False  ...
# 2        white      female  vehicular       False           False  ...
# 3        white        male  vehicular       False           False  ...
# 4     hispanic      female  vehicular       False            True  ...
#
#   contraband_weapons contraband_alcohol contraband_other frisk_performed  \
# 0                NaN              False              NaN             NaN
# 1              False              False            False           False
# 2                NaN              False              NaN             NaN
# 3                NaN              False              NaN             NaN
# 4                NaN              False              NaN             NaN
#
#   search_conducted  search_basis reason_for_stop vehicle_type  \
# 0            False           NaN           Speed    Passenger
# 1             True         other             NaN   Commercial
# 2            False           NaN             NaN    Passenger
# 3            False           NaN             NaN   Commercial
# 4            False           NaN             NaN   Commercial
#
#    vehicle_registration_state  raw_Race
# 0                          MA     White
# 1                          MA     White
# 2                          MA     White
# 3                          MA     White
# 4                          MA  Hispanic
#
# [5 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3416238 entries, 0 to 3416237
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   raw_row_number              int64
#  1   date                        object
#  2   location                    object
#  3   county_name                 object
#  4   subject_age                 float64
#  5   subject_race                object
#  6   subject_sex                 object
#  7   type                        object
#  8   arrest_made                 object
#  9   citation_issued             object
#  10  warning_issued              object
#  11  outcome                     object
#  12  contraband_found            object
#  13  contraband_drugs            object
#  14  contraband_weapons          object
#  15  contraband_alcohol          bool
#  16  contraband_other            object
#  17  frisk_performed             object
#  18  search_conducted            bool
#  19  search_basis                object
#  20  reason_for_stop             object
#  21  vehicle_type                object
#  22  vehicle_registration_state  object
#  23  raw_Race                    object
# dtypes: bool(2), float64(1), int64(1), object(20)
# memory usage: 579.9+ MB

# %%
##Convert date to datetype
import datetime
data.date
data["date"] = pd.to_datetime(data.date, format="%Y-%M-%d")
#Extract time
data['time'] = [d.time() for d in data['date']]

# %%
data
# Out:
#          raw_row_number                date       location       county_name  \
# 0                     1 2007-01-06 00:06:00  MIDDLEBOROUGH   Plymouth County
# 1                     2 2007-01-07 00:06:00        SEEKONK    Bristol County
# 2                     3 2007-01-07 00:06:00        MEDFORD  Middlesex County
# 3                     4 2007-01-07 00:06:00        MEDFORD  Middlesex County
# 4                     5 2007-01-07 00:06:00        EVERETT  Middlesex County
# ...                 ...                 ...            ...               ...
# 3416233         3418294 2015-01-22 00:12:00      DARTMOUTH    Bristol County
# 3416234         3418295 2015-01-27 00:12:00     FALL RIVER    Bristol County
# 3416235         3418296 2015-01-06 00:01:00    NORTHAMPTON  Hampshire County
# 3416236         3418297 2015-01-06 00:01:00        HOLYOKE    Hampden County
# 3416237         3418298 2015-01-06 00:01:00        HOLYOKE    Hampden County
#
#          subject_age            subject_race subject_sex       type  \
# 0               33.0                   white        male  vehicular
# 1               36.0                   white        male  vehicular
# 2               56.0                   white      female  vehicular
# 3               37.0                   white        male  vehicular
# 4               22.0                hispanic      female  vehicular
# ...              ...                     ...         ...        ...
# 3416233         25.0                   white        male  vehicular
# 3416234         52.0  asian/pacific islander      female  vehicular
# 3416235         41.0                   white      female  vehicular
# 3416236         26.0                   white        male  vehicular
# 3416237         52.0                   white        male  vehicular
#
#         arrest_made citation_issued  ... contraband_alcohol contraband_other  \
# 0             False            True  ...              False              NaN
# 1             False           False  ...              False            False
# 2             False           False  ...              False              NaN
# 3             False           False  ...              False              NaN
# 4             False            True  ...              False              NaN
# ...             ...             ...  ...                ...              ...
# 3416233       False            True  ...              False              NaN
# 3416234       False            True  ...              False              NaN
# 3416235       False           False  ...              False              NaN
# 3416236       False            True  ...              False              NaN
# 3416237       False            True  ...              False              NaN
#
#         frisk_performed search_conducted search_basis  reason_for_stop  \
# 0                   NaN            False          NaN            Speed
# 1                 False             True        other              NaN
# 2                   NaN            False          NaN              NaN
# 3                   NaN            False          NaN              NaN
# 4                   NaN            False          NaN              NaN
# ...                 ...              ...          ...              ...
# 3416233             NaN            False          NaN            Speed
# 3416234             NaN            False          NaN            Speed
# 3416235             NaN            False          NaN              NaN
# 3416236             NaN            False          NaN              NaN
# 3416237             NaN            False          NaN              NaN
#
#         vehicle_type vehicle_registration_state                   raw_Race  \
# 0          Passenger                         MA                      White
# 1         Commercial                         MA                      White
# 2          Passenger                         MA                      White
# 3         Commercial                         MA                      White
# 4         Commercial                         MA                   Hispanic
# ...              ...                        ...                        ...
# 3416233    Passenger                         MA                      White
# 3416234    Passenger                         MA  Asian or Pacific Islander
# 3416235    Passenger                         MA                      White
# 3416236    Passenger                         MA                      White
# 3416237    Passenger                         MA                      White
#
#              time
# 0        00:06:00
# 1        00:06:00
# 2        00:06:00
# 3        00:06:00
# 4        00:06:00
# ...           ...
# 3416233  00:12:00
# 3416234  00:12:00
# 3416235  00:01:00
# 3416236  00:01:00
# 3416237  00:01:00
#
# [3416238 rows x 25 columns]

# %%
#Convering race, sex, location etc to categorical
data.iloc[:,np.r_[2:4,5:8,9:12,19:23]]=data.iloc[:,np.r_[2:4,5:8,9:12,19:23]].astype("category")

# %%
data.info()

# %%
#Checking proportion of missing values
data.isnull().sum()*100/len(data)
# Out:
# raw_row_number                 0.000000
# date                           0.000000
# location                       0.192881
# county_name                    0.192881
# subject_age                    4.251496
# subject_race                   0.000000
# subject_sex                    0.066616
# type                           0.000000
# arrest_made                    0.026546
# citation_issued                0.026546
# warning_issued                 0.026546
# outcome                        0.198019
# contraband_found              98.365711
# contraband_drugs              98.365711
# contraband_weapons            98.365711
# contraband_alcohol             0.000000
# contraband_other              98.365711
# frisk_performed               98.396125
# search_conducted               0.000000
# search_basis                  98.501956
# reason_for_stop               48.285615
# vehicle_type                   0.139641
# vehicle_registration_state     0.270423
# raw_Race                       0.000000
# time                           0.000000
# rise                           0.000000
# set                            0.000000
# sunrise                        0.000000
# sunset                         0.000000
# dtype: float64

# %% [markdown]
# <!-- We will use the KNN Imputer for imputing values into the Age and Sex variables for better precision -->

# %% [markdown]
# We impute null values using an MICE imputer from fancyimpute, a popular algorithm.
# Check imputation algorithms here:
# https://www.kaggle.com/residentmario/simple-techniques-for-missing-data-imputation
#
# # Please fix below code(s) to impute values for age and sex, the missing values are < 1% for sex so we can remove them for more precision for age it is 4.6%

# %%
# from sklearn.impute import KNNImputer

# imputer = KNNImputer(n_neighbors=2, weights="uniform")

# data["subject_age"]= imputer.fit_transform(data[['subject_age']])
# # data['subject_sex'] = imputer.fit_transform(data[['subject_sex']])
# data["subject_age"].isnull().sum()
# print(data['subject_age'])
# # print(data['subject_sex'])

# %%
# Impute the missing values.

# from fancyimpute import MICE
# trans = MICE(verbose=False)
# data["subject_sex"] = trans.complete(data["subject_sex"])

# %%
#Removing null, and unknown values from race
data=data[-data["subject_race"].isin(["other","unknown",np.nan])]
data["subject_race"].unique()
# Out:
# array(['white', 'hispanic', 'black', 'asian/pacific islander'],
#       dtype=object)

# %% [markdown]
# Encoding categorical variables for future analyses

# %%
# One hot encoding race and other categorical variables
import sklearn.preprocessing.LabelEncoder
label_encoder = LabelEncoder()

df['subject_race'] = label_encoder.fit_transform(df['subject_race'])
df['arrest_made'] = label_encoder.fit_transform(df['arrest_made'])
df['citation_issued'] = label_encoder.fit_transform(df['citation_issued'])
df['outcome'] = label_encoder.fit_transform(df['outcome'])
df['contraband_found'] = label_encoder.fit_transform(df['contraband_found'])
df['contraband_drugs'] = label_encoder.fit_transform(df['contraband_drugs'])
df['contraband_weapons'] = label_encoder.fit_transform(df['contraband_weapons'])
df['contraband_alcohol'] = label_encoder.fit_transform(df['contraband_alcohol'])
df['contraband_other'] = label_encoder.fit_transform(df['contraband_other'])

# %%
from suntime import Sun, SunTimeException

latitude = 42.407211
longitude = -71.382439

sun = Sun(latitude, longitude)

# Get sunrise and sunset in UTC
sunrise=[]
sunset=[]
for value in data["date"]:
    sunrise.append(sun.get_sunrise_time(value))
    sunset.append(sun.get_sunset_time(value))
    format(value.strftime('%H:%M'))
                  
data["sunrise"]=sunrise
data["sunset"]=sunset
print(data)
# Out:
#          raw_row_number       date       location       county_name  \
# 0                     1 2007-06-06  MIDDLEBOROUGH   Plymouth County
# 1                     2 2007-06-07        SEEKONK    Bristol County
# 2                     3 2007-06-07        MEDFORD  Middlesex County
# 3                     4 2007-06-07        MEDFORD  Middlesex County
# 4                     5 2007-06-07        EVERETT  Middlesex County
# ...                 ...        ...            ...               ...
# 3416233         3418294 2015-12-22      DARTMOUTH    Bristol County
# 3416234         3418295 2015-12-27     FALL RIVER    Bristol County
# 3416235         3418296 2015-01-06    NORTHAMPTON  Hampshire County
# 3416236         3418297 2015-01-06        HOLYOKE    Hampden County
# 3416237         3418298 2015-01-06        HOLYOKE    Hampden County
#
#          subject_age            subject_race subject_sex       type  \
# 0               33.0                   white        male  vehicular
# 1               36.0                   white        male  vehicular
# 2               56.0                   white      female  vehicular
# 3               37.0                   white        male  vehicular
# 4               22.0                hispanic      female  vehicular
# ...              ...                     ...         ...        ...
# 3416233         25.0                   white        male  vehicular
# 3416234         52.0  asian/pacific islander      female  vehicular
# 3416235         41.0                   white      female  vehicular
# 3416236         26.0                   white        male  vehicular
# 3416237         52.0                   white        male  vehicular
#
#         arrest_made citation_issued  ... search_basis reason_for_stop  \
# 0             False            True  ...          NaN           Speed
# 1             False           False  ...        other             NaN
# 2             False           False  ...          NaN             NaN
# 3             False           False  ...          NaN             NaN
# 4             False            True  ...          NaN             NaN
# ...             ...             ...  ...          ...             ...
# 3416233       False            True  ...          NaN           Speed
# 3416234       False            True  ...          NaN           Speed
# 3416235       False           False  ...          NaN             NaN
# 3416236       False            True  ...          NaN             NaN
# 3416237       False            True  ...          NaN             NaN
#
#         vehicle_type vehicle_registration_state                   raw_Race  \
# 0          Passenger                         MA                      White
# 1         Commercial                         MA                      White
# 2          Passenger                         MA                      White
# 3         Commercial                         MA                      White
# 4         Commercial                         MA                   Hispanic
# ...              ...                        ...                        ...
# 3416233    Passenger                         MA                      White
# 3416234    Passenger                         MA  Asian or Pacific Islander
# 3416235    Passenger                         MA                      White
# 3416236    Passenger                         MA                      White
# 3416237    Passenger                         MA                      White
#
#              time                      rise                       set  \
# 0        00:00:00 2007-06-06 09:09:00+00:00 2007-06-06 00:19:00+00:00
# 1        00:00:00 2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# 2        00:00:00 2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# 3        00:00:00 2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# 4        00:00:00 2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# ...           ...                       ...                       ...
# 3416233  00:00:00 2015-12-22 12:12:00+00:00 2015-12-22 21:16:00+00:00
# 3416234  00:00:00 2015-12-27 12:14:00+00:00 2015-12-27 21:19:00+00:00
# 3416235  00:00:00 2015-01-06 12:15:00+00:00 2015-01-06 21:28:00+00:00
# 3416236  00:00:00 2015-01-06 12:15:00+00:00 2015-01-06 21:28:00+00:00
# 3416237  00:00:00 2015-01-06 12:15:00+00:00 2015-01-06 21:28:00+00:00
#
#                           sunrise                    sunset
# 0       2007-06-06 09:09:00+00:00 2007-06-06 00:19:00+00:00
# 1       2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# 2       2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# 3       2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# 4       2007-06-07 09:09:00+00:00 2007-06-07 00:20:00+00:00
# ...                           ...                       ...
# 3416233 2015-12-22 12:12:00+00:00 2015-12-22 21:16:00+00:00
# 3416234 2015-12-27 12:14:00+00:00 2015-12-27 21:19:00+00:00
# 3416235 2015-01-06 12:15:00+00:00 2015-01-06 21:28:00+00:00
# 3416236 2015-01-06 12:15:00+00:00 2015-01-06 21:28:00+00:00
# 3416237 2015-01-06 12:15:00+00:00 2015-01-06 21:28:00+00:00
#
# [3416238 rows x 29 columns]

# %% [markdown]
# We now create new values for search, success rates

# %%
group_agg = data.groupby(["date"]).agg({
  "search_conducted" : lambda x: x.mean(skipna = True), 
  "frisk_performed" : lambda x: x.mean(skipna = True), 
  "contraband_found" : lambda x: x.mean(skipna = True)
  })

# %%
group_agg.rename(columns={"search_conducted" : 'search_rate', "frisk_performed" : 'frisk_rate',"contraband_found":'success_rate'}, inplace=True)

print(group_agg)
# Out:
#             search_rate  frisk_rate  success_rate
# date
# 2007-01-01     0.039474         0.5      0.333333
# 2007-01-02     0.021739         0.0      1.000000
# 2007-01-03     0.000000         NaN           NaN
# 2007-01-04     0.000000         NaN           NaN
# 2007-01-05     0.024390         0.0      0.000000
# ...                 ...         ...           ...
# 2015-12-27     0.009747         0.4      0.600000
# 2015-12-28     0.008997         0.0      0.571429
# 2015-12-29     0.008380         0.0      0.666667
# 2015-12-30     0.003106         0.0      0.000000
# 2015-12-31     0.008902         0.0      1.000000
#
# [3287 rows x 3 columns]
